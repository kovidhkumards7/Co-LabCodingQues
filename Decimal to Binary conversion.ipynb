# %%
a=int(input('enter number  '))
b=[]
while a>0:
    b.append(a%2)
    a=int(a/2)
c=b[::-1]
for i in c:
    print(i,end=' ')
# Out:
# enter number  Ab
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-31db02d66e91> in <module>()
# ----> 1 a=int(input('enter number  '))
#       2 b=[]
#       3 while a>0:
#       4     b.append(a%2)
#       5     a=int(a/2)
#
# ValueError: invalid literal for int() with base 10: 'Ab'
